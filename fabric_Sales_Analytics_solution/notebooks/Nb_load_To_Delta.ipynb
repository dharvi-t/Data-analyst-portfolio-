# %%
## converting sorce file to delta table (bronze layer)
df= spark.read.format('csv')\
   .option('header', 'true') \
   .option('inferSchema', 'true')\
   .load('Files/raw/sales_data.csv')
df.write.format('delta')\
   .mode('overwrite')\
   .saveAsTable('bronze_sales')
# Out:
# StatementMeta(, d9bbdb25-4872-4b0d-be63-4a28056f5343, 4, Finished, Available, Finished, False)
